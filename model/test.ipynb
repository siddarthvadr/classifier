# %%
import os
import shutil
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
face_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_frontalface_alt.xml') #* importing face xml
eye_cascade = cv2.CascadeClassifier('opencv/haarcascades/haarcascade_eye_tree_eyeglasses.xml')#* importing eye xml

# %%
def get_cropped_img(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    roi_color=[]
    

    
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color.append(img[y:y+h, x:x+w])
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            print(len(roi_color))
    
    

get_cropped_img('testimg/binny.jpg')
# Out:
# 1
# 2

# %%
img = cv2.imread('testimg/binny.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
roi_color=[]
    

    
for (x,y,w,h) in faces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color.append(img[y:y+h, x:x+w])
    eyes = eye_cascade.detectMultiScale(roi_gray)

if len(eyes) >= 2:
    
    for face in roi_color:
        plt.imshow(face)
        plt.show()
print(type(face))
print(type(roi_color)) 
face[0]
roi_color[0]
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
# array([[[198, 191, 174],
#         [198, 192, 173],
#         [199, 193, 174],
#         ...,
#         [155, 148, 139],
#         [161, 154, 145],
#         [165, 156, 146]],
#
#        [[198, 191, 174],
#         [198, 192, 173],
#         [199, 193, 174],
#         ...,
#         [152, 145, 136],
#         [153, 146, 137],
#         [154, 145, 135]],
#
#        [[198, 191, 174],
#         [198, 192, 173],
#         [199, 193, 174],
#         ...,
#         [147, 140, 131],
#         [150, 143, 134],
#         [153, 144, 134]],
#
#        ...,
#
#        [[194, 200, 205],
#         [194, 200, 205],
#         [194, 200, 205],
#         ...,
#         [124,  94,  75],
#         [124,  94,  75],
#         [124,  94,  75]],
#
#        [[194, 200, 205],
#         [194, 200, 205],
#         [194, 200, 205],
#         ...,
#         [126,  96,  77],
#         [123,  93,  74],
#         [121,  91,  72]],
#
#        [[194, 200, 205],
#         [194, 200, 205],
#         [194, 200, 205],
#         ...,
#         [125,  95,  76],
#         [122,  92,  73],
#         [121,  91,  72]]], dtype=uint8)
